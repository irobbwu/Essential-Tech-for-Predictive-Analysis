# %% [markdown]
# #  Data Query

# %% [markdown]
# 1. .loc,  Data Query by name of row or column
# 2. .iloc,  Data Query by the index number of row of column
# 3. .where
# 4. .quert

# %%
import pandas as pd

# %% [markdown]
# ## .loc

# %%
data = pd.read_csv('/Users/yasmine/Documents/learning/language/python/Essential-Tech-for-Predictive-Analysis/01. Pandas/datas/beijing_tianqi/beijing_tianqi_2018.csv')
data
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %% [markdown]
# ###### Set index in Pandas

# %%
data.set_index('ymd', inplace = True)
data

# inplace = False means that a new object was created
# inplace = True means modify the origin dataframe
# newdata = data.set_index('ymd', inplace = False)
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ...           ...    ...    ...       ...    ...  ...     ...       ...
# 2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 8 columns]

# %%
data.index
# Out:
# Index(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#        '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09', '2018-01-10',
#        ...
#        '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26',
#        '2018-12-27', '2018-12-28', '2018-12-29', '2018-12-30', '2018-12-31'],
#       dtype='object', name='ymd', length=365)

# %%
data.head()
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
# Delete °C
data.loc[:, 'bWendu'] = data['bWendu'].str.replace('℃','').astype('int32')
data.loc[:, 'yWendu'] = data['yWendu'].str.replace('℃','').astype('int32')

# %%
data.dtypes
# Out:
# bWendu        int32
# yWendu        int32
# tianqi       object
# fengxiang    object
# fengli       object
# aqi           int64
# aqiInfo      object
# aqiLevel      int64
# dtype: object

# %%
data.head()
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1

# %%
data.loc['2018-01-02', 'bWendu']
# Out:
# 2

# %%
data.loc['2018-01-02', ['bWendu','yWendu']]
# Out:
# bWendu     2
# yWendu    -5
# Name: 2018-01-02, dtype: object

# %%
data.loc[['2018-01-02','2018-01-03'], 'yWendu']
# Out:
# ymd
# 2018-01-02   -5
# 2018-01-03   -5
# Name: yWendu, dtype: int32

# %%
data.loc[['2018-01-02','2018-01-03'], ['bWendu','yWendu']]
# Out:
#             bWendu  yWendu
# ymd
# 2018-01-02       2      -5
# 2018-01-03       2      -5

# %%
data.loc['2018-01-02':'2018-01-10', ['bWendu','yWendu']]
# Out:
#             bWendu  yWendu
# ymd
# 2018-01-02       2      -5
# 2018-01-03       2      -5
# 2018-01-04       0      -8
# 2018-01-05       3      -6
# 2018-01-06       2      -5
# 2018-01-07       2      -4
# 2018-01-08       2      -6
# 2018-01-09       1      -8
# 2018-01-10      -2     -10

# %%
data.loc[data['yWendu']<-10]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-23      -4     -12      晴       西北风   3-4级   31       优         1
# 2018-01-24      -4     -11      晴       西南风   1-2级   34       优         1
# 2018-01-25      -3     -11     多云       东北风   1-2级   27       优         1
# 2018-12-26      -2     -11   晴~多云       东北风     2级   26       优         1
# 2018-12-27      -5     -12   多云~晴       西北风     3级   48       优         1
# 2018-12-28      -3     -11      晴       西北风     3级   40       优         1
# 2018-12-29      -3     -12      晴       西北风     2级   29       优         1
# 2018-12-30      -2     -11   晴~多云       东北风     1级   31       优         1

# %%
data.loc[(data['bWendu']<=30)&(data['yWendu']>=15)&(data['tianqi']=='晴')]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-04-28      27      17      晴       西南风   3-4级  125    轻度污染         3
# 2018-05-13      30      17      晴        南风   1-2级   68       良         2
# 2018-05-23      29      15      晴       西南风   3-4级  153    中度污染         4
# 2018-05-28      30      16      晴       西北风   4-5级  178    中度污染         4
# 2018-08-24      30      20      晴        北风   1-2级   40       优         1
# 2018-09-03      30      19      晴        北风   3-4级   70       良         2
# 2018-09-07      27      16      晴       西北风   3-4级   22       优         1
# 2018-09-09      28      16      晴       西南风   1-2级   51       良         2

# %%
data.loc[lambda data: (data['bWendu']<=30)&(data['yWendu']>=15)]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-04-28      27      17      晴       西南风   3-4级  125    轻度污染         3
# 2018-04-29      30      16     多云        南风   3-4级  193    中度污染         4
# 2018-05-04      27      16   晴~多云       西南风   1-2级   86       良         2
# 2018-05-09      29      17   晴~多云       西南风   3-4级   79       良         2
# 2018-05-10      26      18     多云        南风   3-4级  118    轻度污染         3
# ...            ...     ...    ...       ...    ...  ...     ...       ...
# 2018-09-15      26      15     多云        北风   3-4级   42       优         1
# 2018-09-17      27      17   多云~阴        北风   1-2级   37       优         1
# 2018-09-18      25      17   阴~多云       西南风   1-2级   50       优         1
# 2018-09-19      26      17     多云        南风   1-2级   52       良         2
# 2018-09-20      27      16     多云       西南风   1-2级   63       良         2
#
# [64 rows x 8 columns]

# %%
def query_my_data(df):
    return df.index.str.startswith('2018-09')&df['aqiLevel'] == 1

data.loc[query_my_data(data), :]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-09-01      27      19   阴~小雨        南风   1-2级   50       优         1
# 2018-09-04      31      18      晴       西南风   3-4级   24       优         1
# 2018-09-05      31      19   晴~多云       西南风   3-4级   34       优         1
# 2018-09-06      27      18   多云~晴       西北风   4-5级   37       优         1
# 2018-09-07      27      16      晴       西北风   3-4级   22       优         1
# 2018-09-08      27      15   多云~晴        北风   1-2级   28       优         1
# 2018-09-13      29      20   多云~阴        南风   1-2级  107    轻度污染         3
# 2018-09-14      28      19  小雨~多云        南风   1-2级  128    轻度污染         3
# 2018-09-15      26      15     多云        北风   3-4级   42       优         1
# 2018-09-16      25      14   多云~晴        北风   1-2级   29       优         1
# 2018-09-17      27      17   多云~阴        北风   1-2级   37       优         1
# 2018-09-18      25      17   阴~多云       西南风   1-2级   50       优         1
# ...
